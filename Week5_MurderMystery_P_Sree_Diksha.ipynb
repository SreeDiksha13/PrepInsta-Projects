# %% [markdown]
# # ***SQL Muderer Mystery ***

# %%
i import pandas as pd
import sqlite3 as sql

# %%
data= sql.connect("/content/sql-murder-mystery.db")

# %%
query= """
SELECT name
FROM sqlite_master
WHERE type = 'table';
"""

pd.read_sql(query,data)
# Out:
#                      name
# 0      crime_scene_report
# 1         drivers_license
# 2                  person
# 3  facebook_event_checkin
# 4               interview
# 5      get_fit_now_member
# 6    get_fit_now_check_in
# 7                  income
# 8                solution

# %%
query
# Out:
# "\nSELECT name \nFROM sqlite_master\nWHERE type = 'table';\n"

# %%
query= """
SELECT *
FROM crime_scene_report;
"""
pd.read_sql(query,data)
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
#Getting the reports for SQL City
crime_reports_sql= """
SELECT *
FROM crime_scene_report
WHERE city="SQL City";
"""

pd.set_option('display.max_colwidth',None)
pd.read_sql(crime_reports_sql,data)
# Out:
#        date     type  \
# 0  20180215   murder
# 1  20180215   murder
# 2  20170712    theft
# 3  20170820    arson
# 4  20171110  robbery
# 5  20180103  bribery
# 6  20180115  assault
# 7  20180115  assault
# 8  20180115   murder
#
#                                                                                                                                                                                                                                                               description  \
# 0                                                                                                                                                                                                                                              REDACTED REDACTED REDACTED
# ...

# %%
#Querying for report on Jan 15 for Murder
crime_report= """
SELECT *
FROM crime_scene_report
WHERE city="SQL City" and date=20180115 and type="murder";

"""

pd.set_option('display.max_colwidth',None)
pd.read_sql(crime_report,data)
# Out:
#        date    type  \
# 0  20180115  murder
#
#                                                                                                                                                                                  description  \
# 0  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#        city
# 0  SQL City

# %%
#Analysing the person table
query= """
SELECT *
FROM person;
"""
pd.set_option('display.max_colwidth',None)
pd.read_sql(query,data)
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
#Checking for Witness 1 based on the report
witness1= """
SELECT *
FROM person
WHERE address_street_name = "Northwestern Dr"
AND address_number = (SELECT MAX(address_number) FROM person WHERE address_street_name = "Northwestern Dr");

"""
pd.set_option('display.max_colwidth',None)
pd.read_sql(witness1,data)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
#Checking for Witness 2 based on the report
witness2= """
SELECT *
FROM person
WHERE name LIKE "Annabel%"
AND address_street_name = "Franklin Ave";


"""
pd.set_option('display.max_colwidth',None)
pd.read_sql(witness2,data)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
#Looking into witness interviews
interview= """
SELECT *
FROM interview
WHERE person_id IN (14887, 16371);

"""
pd.set_option('display.max_colwidth',None)
pd.read_sql(interview,data)
# Out:
#    person_id  \
# 0      14887
# 1      16371
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# 1                                                                                                            I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
#Checking the gym data based on witness statement
gym= """
SELECT *
FROM get_fit_now_member;
"""
pd.read_sql(gym,data)
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
gym= """
SELECT *
FROM get_fit_now_member
WHERE membership_status= "gold" and id LIKE "%48Z%";
"""
pd.read_sql(gym,data)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
#Narrowing down the suspects
suspects= """
SELECT *
FROM person
WHERE id IN (28819,67318);
"""
pd.read_sql(suspects,data)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  28819   Joe Germuska      173289             111                Fisk Rd
# 1  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  138909730
# 1  871539279

# %%
gym_checkin= """
SELECT *
FROM get_fit_now_check_in;

"""
pd.read_sql(gym_checkin,data)
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
#Further narrowing down based on checkin date
gym= """
SELECT *
FROM get_fit_now_check_in
WHERE membership_id IN ("48Z7A", "48Z55") and check_in_date= 20180109;
"""
pd.read_sql(gym,data)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %%
car= """
SELECT *
FROM drivers_license
wHERE plate_number LIKE "%H42W%";
"""
pd.read_sql(car,data)
# Out:
#        id  age  height eye_color hair_color  gender plate_number   car_make  \
# 0  183779   21      65      blue     blonde  female       H42W0X     Toyota
# 1  423327   30      70     brown      brown    male       0H42W2  Chevrolet
# 2  664760   21      71     black      black    male       4H42WR     Nissan
#
#   car_model
# 0     Prius
# 1  Spark LS
# 2    Altima

# %%
#Finding the final suspect based on car details
suspects= """
SELECT *
FROM person
WHERE id IN (28819,67318) and license_id IN (183779,423327,66760);
"""
pd.read_sql(suspects,data)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %%
#FINAL MURDERER
gym = """
SELECT *
FROM get_fit_now_member
WHERE name= "Jeremy Bowers";
"""
pd.read_sql(gym,data)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
murderer = """
SELECT *
FROM person
WHERE name= "Jeremy Bowers";
"""
pd.read_sql(murderer,data)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %%
#Murderer interview
interviewm= """
SELECT *
FROM interview
WHERE person_id= 67318;

"""
pd.set_option('display.max_colwidth',None)
pd.read_sql(interviewm,data)
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
query1= '''
SELECT *
FROM drivers_license
WHERE car_make = "Tesla" AND car_model = "Model S" AND
gender = "female" AND hair_color = "red";
'''
pd.read_sql_query(query1, con)

# %%
#personal details of the above three woman are:
query2 = '''
SELECT *
FROM person
WHERE license_id = "202298" OR license_id = "291182" OR license_id = "918773";
'''
pd.read_sql_query(query2, con)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6cfd2d2f388a> in <cell line: 7>()
#       5 WHERE license_id = "202298" OR license_id = "291182" OR license_id = "918773";
#       6 '''
# ----> 7 pd.read_sql_query(query2, con)
#
# NameError: name 'pd' is not defined

# %%
#checking the event SQL symphony concert
query3 = '''
SELECT person_id, count(*), event_name
FROM facebook_event_checkin
GROUP BY person_id
having count(*) = 3 AND event_name = "SQL Symphony Concert" AND date like "%201712%";
'''
pd.read_sql_query(query3, con)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c27758d47f93> in <cell line: 8>()
#       6 having count(*) = 3 AND event_name = "SQL Symphony Concert" AND date like "%201712%";
#       7 '''
# ----> 8 pd.read_sql_query(query3, con)
#
# NameError: name 'pd' is not defined

# %%
"""
REPORT:
The muderer is Jeremy Bowers-
age: 30
address :Washington Pl, Apt 3A
He was hired by Miranda Priestly.
Jeremy was indentified by witnesses- Annabel Miller and Morty Schapiro.
They witnessed him from the gym= get fit now,where Jeremy is a gold member.

Jeremy was seen with his gym bag with his membership id on it. Annabel Miller also witnessed him get into
his car- A chevrolet.

"""
